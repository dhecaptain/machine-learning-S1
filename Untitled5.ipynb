# %%
import matplotlib.pyplot as plt
import numpy as np
import sys

# %%
xpoint = np.array([1,2,3,4,5])
ypoints = np.array([6,7,8,9,10])

plt.plot(xpoint,ypoints,marker='*',color='hotpink',ms=20,mfc='red',mec='pink')
plt.show()

# %% [markdown]
# MATPLOTLIB LINE
# We use linestyle to specify the type of style to use. Also shortHand as ls
# To specify the color of the line use color or shorthand as c
# linestyle cans be dotted,dashed,
# Also you can specify the linewidth by linewidth property or shorthand as lw e.g lw='20.5'

# %%
from sklearn_dataset import Diabetes
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from sklearn_dataset import Diabetes
#
# ModuleNotFoundError: No module named 'sklearn_dataset'

# %%
np.random.seed(0)
x = np.random.rand(100,1)
y = 4 + 3* x +np.random.randn(100,1)

plt.plot(x,y)
plt.ylabel('y')
plt.xlabel('x')
plt.grid(axis='y',ls=':')
plt.show()

# %%
#crating A  linear regression model
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(x,y)

print(f"intercept: {model.intercept_[0]}")
print(f"coefficient: {model.coef_[0][0]}")

plt.scatter(x,y)
plt.plot(x,model.predict(x),c='r')
plt.xlabel('X')
plt.ylabel('Y')
plt.title("Linear Regression")
plt.show()
# Out:
# intercept: 4.222151077447229
# coefficient: 2.9369350214020384
