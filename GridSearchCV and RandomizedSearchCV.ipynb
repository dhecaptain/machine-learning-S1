# %% [markdown]
# ## Hyperparameter Tuning:
#     1. GridSearchCV
#     2. RandomizedSearchCV

# %%
# importing necessary modules
import numpy as np
import pandas as pd
import sklearn.datasets
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# the dataset will be of breast cancer

# %%
# loading the dataset
breast_cancer = sklearn.datasets.load_breast_cancer()

# %%
# loading the data into a dataframe
data = pd.DataFrame(breast_cancer.data,columns=breast_cancer.feature_names)

# %%
data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
# adding the label 'target' column into the data
data['target'] = breast_cancer.target

# %%
data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
data.shape
# Out:
# (569, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
# check for missing values
data.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
# checking for the distribution of the target variable
data["target"].value_counts()
# Out:
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
# separating the data 
X =  data.drop("target",axis=1)
y = data["target"]

# %%
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int32

# %%
X = np.asarray(X)
y = np.asarray(y)
X
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]])

# %% [markdown]
# ## GridSearchCV

# %% [markdown]
# GridSearchCV is used for determining the best parameter for the model

# %%
# loading the SVC
model = SVC()

# %%
# hyperparameters

parameters = {
    'kernel':['linear','poly','rbf','sigmoid'],
    'C':[1,5,10,20]
}

# %%
# grid search 
classifier = GridSearchCV(model,parameters,cv=5)

# %%
# fitting the data to our model
classifier.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([3.09450130e+00, 6.79750443e-03, 9.38906670e-03, 2.27949142e-02,
#         5.58075118e+00, 7.10997581e-03, 7.99860954e-03, 2.03879833e-02,
#         8.37370505e+00, 8.17532539e-03, 7.97548294e-03, 2.02041626e-02,
#         1.40757839e+01, 8.01053047e-03, 8.60180855e-03, 2.02105522e-02]),
#  'std_fit_time': array([1.22965184e+00, 3.73812822e-04, 7.94297593e-04, 1.83530963e-03,
#         1.15443229e+00, 8.87604219e-04, 5.95781947e-04, 4.79844874e-04,
#         1.72696127e+00, 7.40369309e-04, 2.94655271e-05, 1.14732435e-03,
#         4.50419492e+00, 3.15674122e-05, 1.03141794e-03, 1.48435502e-03]),
#  'mean_score_time': array([0.00259275, 0.00198932, 0.00521035, 0.0064033 , 0.00202618,
#         0.00200529, 0.00460138, 0.00540042, 0.00179052, 0.00223322,
#         0.00401249, 0.00580664, 0.00299172, 0.00340376, 0.00499892,
#         0.00651722]),
#  'std_score_time': array([8.05067199e-04, 2.34511792e-05, 3.94879886e-04, 7.99489809e-04,
# ...

# %%
# Best Parameter 

best_parameters = classifier.best_params_
best_parameters
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
# Determining the highest accuracy
highest_accuracy = classifier.best_score_
highest_accuracy
# Out:
# 0.9525694767893185

# %%
# load the results to pandas dataframe
result = pd.DataFrame(classifier.cv_results_)

# %%
result.head(8)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       3.094501      1.229652         0.002593        0.000805       1
# 1       0.006798      0.000374         0.001989        0.000023       1
# 2       0.009389      0.000794         0.005210        0.000395       1
# 3       0.022795      0.001835         0.006403        0.000799       1
# 4       5.580751      1.154432         0.002026        0.001108       5
# 5       0.007110      0.000888         0.002005        0.000034       5
# 6       0.007999      0.000596         0.004601        0.000469       5
# 7       0.020388      0.000480         0.005400        0.000832       5
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.947368
# 1         poly     {'C': 1, 'kernel': 'poly'}           0.842105
# 2          rbf      {'C': 1, 'kernel': 'rbf'}           0.850877
# ...

# %%
grid_search_result =result[["param_C","param_kernel","mean_test_score"]]

# %%
grid_search_result
# Out:
#    param_C param_kernel  mean_test_score
# 0        1       linear         0.945536
# 1        1         poly         0.908663
# 2        1          rbf         0.912172
# 3        1      sigmoid         0.460441
# 4        5       linear         0.950815
# 5        5         poly         0.922729
# 6        5          rbf         0.931501
# 7        5      sigmoid         0.411178
# 8       10       linear         0.952569
# 9       10         poly         0.920975
# 10      10          rbf         0.922714
# 11      10      sigmoid         0.402391
# 12      20       linear         0.949061
# 13      20         poly         0.919221
# 14      20          rbf         0.920944
# 15      20      sigmoid         0.398867

# %% [markdown]
# Highest Accuracy = 95.2%
#
# Best Parameters = {'C':10,'kernel':'linear'}

# %% [markdown]
# # **RandomizedSearchCV**

# %%
# load the SVC model
model =SVC()

# %%
# hyperparmeters
parameters = {
    'kernel':['linear','poly','rbf','sigmoid'],
    'C':[1,5,10,20]
}

# %%
# grid search
classifier = RandomizedSearchCV(model,parameters,cv=5)

# %%
# fit the  model
classifier.fit(X,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(),
#                    param_distributions={'C': [1, 5, 10, 20],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([2.61975765e-02, 2.72319446e+00, 2.23784924e-02, 1.50667954e+01,
#         8.86845589e-03, 9.38568115e-03, 7.20906258e-03, 6.41460195e+00,
#         8.78124237e-03, 8.91742797e+00]),
#  'std_fit_time': array([5.45566812e-03, 1.04923115e+00, 2.34519151e-03, 4.94430406e+00,
#         1.73715076e-03, 2.02852266e-03, 7.62195000e-04, 1.55483704e+00,
#         1.31045803e-03, 1.86098141e+00]),
#  'mean_score_time': array([0.00700164, 0.00180111, 0.00543089, 0.00201526, 0.00667791,
#         0.00280342, 0.00240078, 0.00222464, 0.00442133, 0.00220265]),
#  'std_score_time': array([0.00352252, 0.00040193, 0.00078205, 0.00061429, 0.0017436 ,
#         0.00077636, 0.00049084, 0.00077511, 0.00049457, 0.0014731 ]),
#  'param_kernel': masked_array(data=['sigmoid', 'linear', 'sigmoid', 'linear', 'rbf',
#                     'poly', 'poly', 'linear', 'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False,
# ...

# %%
# Best Parameter 

best_parameters = classifier.best_params_
best_parameters
# Out:
# {'kernel': 'linear', 'C': 10}

# %%
# Determining the highest accuracy
highest_accuracy = classifier.best_score_
highest_accuracy
# Out:
# 0.9525694767893185

# %%
# load the results to pandas dataframe
result = pd.DataFrame(classifier.cv_results_)

# %%
grid_search_result =result[["param_C","param_kernel","mean_test_score"]]

# %%
grid_search_result
# Out:
#   param_C param_kernel  mean_test_score
# 0      10      sigmoid         0.402391
# 1       1       linear         0.945536
# 2       5      sigmoid         0.411178
# 3      20       linear         0.949061
# 4       5          rbf         0.931501
# 5      10         poly         0.920975
# 6       1         poly         0.908663
# 7       5       linear         0.950815
# 8      20          rbf         0.920944
# 9      10       linear         0.952569
